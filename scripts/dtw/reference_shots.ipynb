# %%
import pandas as pd

# %%
dir = '/Users/emilio/Documents/Winner Way/scripts/dtw/reports/'
allvsreference = pd.read_csv(f'{dir}all_vs_references.csv')
best_matches = pd.read_csv(f'{dir}best_matches.csv')

# %% [markdown]
# ### Best Matches

# %%
best_matches
# Out:
#                      shot_id1         player1                 shot_id2  \
# 0     roger_federer_bh_ft1_01   Roger Federer  roger_federer_bh_ft1_02
# 1     roger_federer_bh_ft1_03   Roger Federer  roger_federer_bh_ft1_02
# 2     roger_federer_bh_ft1_04   Roger Federer  roger_federer_bh_ft1_02
# 3    carlos_alcaraz_bh_ft2_01  Carlos Alcaraz  roger_federer_bh_ft1_02
# 4     roger_federer_bh_sl1_02   Roger Federer  roger_federer_bh_sl1_01
# ..                        ...             ...                      ...
# 273   novak_djokovic_sv_sl_06  Novak Djokovic  carlos_alcaraz_sv_sl_02
# 274   novak_djokovic_sv_sl_02  Novak Djokovic  carlos_alcaraz_sv_sl_02
# 275   novak_djokovic_sv_sl_03  Novak Djokovic  novak_djokovic_sv_sl_01
# 276   novak_djokovic_sv_sl_04  Novak Djokovic  novak_djokovic_sv_sl_01
# 277   carlos_alcaraz_sv_sl_01  Carlos Alcaraz  novak_djokovic_sv_sl_01
#
#             player2 stroke_type1 spin_type1 stroke_type2 spin_type2  \
# ...
